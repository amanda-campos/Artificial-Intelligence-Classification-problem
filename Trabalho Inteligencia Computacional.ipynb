# %%
import numpy as np 
import pandas as pd
import seaborn as sns
df = pd.read_csv(r"C:\Users\Amanda\Desktop\bank-additional.csv",sep=';')
df.head(5)
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
df['y'].value_counts()
# Out:
# no     3668
# yes     451
# Name: y, dtype: int64

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
df['marital'].value_counts()
# Out:
# married     2509
# single      1153
# divorced     446
# unknown       11
# Name: marital, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

df.hist(bins=20, figsize=(14,10), color='#E14906')
plt.show()

# %%
df['y'].value_counts()
# Out:
# 0    3668
# 1     451
# Name: y, dtype: int64

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed  \
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
import seaborn as sns
sns.set(style="ticks")

sns.pairplot(df, palette="Set1")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
fig = plt.figure(figsize=(12,8))
df['y'] = LabelEncoder().fit_transform(df['y'])



# Separate both dataframes into 
numeric_df = df.select_dtypes(exclude="object")
# categorical_df = df.select_dtypes(include="object")

corr_numeric = numeric_df.corr()


sns.heatmap(corr_numeric, cbar=True, cmap="RdBu_r")
plt.title("Matriz de Correlação", fontsize=16)
plt.show()

# %%
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri         2    999         0  nonexistent
# 1  telephone   may         fri         4    999         0  nonexistent
# 2  telephone   jun         wed         1    999         0  nonexistent
# 3  telephone   jun         fri         3    999         0  nonexistent
# 4   cellular   nov         mon         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# ...

# %%
#MATRIZ DE DISTÂNCIAS
import numpy as np 
import pandas as pd
import seaborn as sns
import scipy.spatial as spatial
df = pd.read_csv(r"C:\Users\Amanda\Desktop\bank-additional.csv",sep=';')
df['y'] = LabelEncoder().fit_transform(df['y'])
df.head()
numeric_df = df.select_dtypes(exclude="object")

pdistmat = spatial.distance.squareform(spatial.distance.pdist(numeric_df))

N = len(numeric_df)
plt.pcolormesh(pdistmat)
plt.colorbar()
plt.xlim([0,N])
plt.ylim([0,N])
plt.show()
print(N)
# Out:
# 4119

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import scipy.spatial as spatial
df = pd.read_csv(r"C:\Users\Amanda\Desktop\bank-additional.csv",sep=';')
df['y'] = LabelEncoder().fit_transform(df['y'])
df.head(5)
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df.plot(kind='box', subplots=True, layout=(2,5), sharex=False, sharey=False, figsize=(17,10))
plt.show()

# %%
sns.pairplot(df, diag_kind='hist', height=1.5, 
             diag_kws={"edgecolor":"k", "alpha":0.8},
             plot_kws={"alpha":0.5})
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
lab = LabelEncoder()
cat = bank[['job','marital','education','housing','contact','month','poutcome','default','loan','deposit']]
df1 = df.apply(lab.fit_transform)
df1.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   12    1        1          2        0        2     0        0      6
# 1   21    7        2          3        0        0     0        1      6
# 2    7    7        1          3        0        2     0        1      4
# 3   20    7        1          2        0        1     1        1      4
# 4   29    0        1          6        0        2     0        0      7
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            0  ...         1     20         0         1             3
# 1            0  ...         3     20         0         1             8
# 2            4  ...         0     20         0         1             9
# 3            0  ...         2     20         0         1             9
# 4            1  ...         0     20         0         1             7
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %% [markdown]
# MODELOS DE CLASSIFICAÇÃO

# %%
df = pd.read_csv(r"C:\Users\Amanda\Desktop\bank-additional.csv",sep=';')
dep = df['y']
df.drop(labels=['y'], axis=1,inplace=True)
df.insert(0, 'y', dep)
df.head()
# housing has a -20% correlation with deposit let's see how it is distributed.
# 52 %
df["housing"].value_counts()/len(df)
# Out:
# yes        0.528041
# no         0.446468
# unknown    0.025492
# Name: housing, dtype: float64

# %%
df["loan"].value_counts()/len(df)
# Out:
# no         0.813061
# yes        0.161447
# unknown    0.025492
# Name: loan, dtype: float64
